# %% [markdown]
# init

# %%
import gensim.models
import gensim
import pandas as pd

DATA_PATH = '/data/'
MODEL_PATH = DATA_PATH + 'models/wv4_ru/'
SOURCE_PATH = DATA_PATH + 'captions/lem/'
PRETRAINED_MODEL_PATH = DATA_PATH + 'models/w2v_pretrained/ruwiki_20180420_300d.txt.bz2'
USE_PRETRAINED_MODEL = True

cities = ['moscow', 'spb']#, 'nyc', 'london']
years = ['2016', '2017', '2018', '2019', '2020']
files = []
for city in cities:
    for year in years:
        files.append([city, year])

def csv_path(path, city, year):
    return path + city + '_posts_' + year + '.csv'

valid_langs = set(['__label__ru'])

# %% [markdown]
# training of model

# %%
from gensim.models import KeyedVectors

class MyCorpus(object):
    iter = 0
    def __iter__(self):
        self.iter += 1
        for city in cities:
            size = 0
            for year in years:
                df = pd.read_csv(csv_path(SOURCE_PATH, city, year))
                df = df[df.lang.isin(valid_langs)]
                size += len(df)
                for s in df['caption']:
                    yield s.split()
            print(f'iter {self.iter} for {city} completed, posts: {size}')
                
        print(f'\niter {self.iter} completed\n')


sentences = MyCorpus()
min_word_count = 50
model = gensim.models.Word2Vec(workers=35, size=300, min_count=min_word_count, window=15, negative=25, sg=1)
'models template was successfully created'
# Out:
# 'models template was successfully created'

# %%
model.build_vocab(sentences)
total_examples=model.corpus_count
print(f'vocab size: {len(model.wv.vocab)}')
if USE_PRETRAINED_MODEL:
    #model_wiki = KeyedVectors.load_word2vec_format(MODEL_PATH + 'ruwiki_20180420_300d.txt.bz2')
    #model.build_vocab([list(model_wiki.vocab.keys()) * min_word_count], update=True)
    model.intersect_word2vec_format(MODEL_PATH + 'ruwiki_20180420_300d.txt.bz2', lockf=1.0)
    print(f'vocab size after loading pretrained model: {len(model.wv.vocab)}')

'models vocab was successfully builded'

# %%
if USE_PRETRAINED_MODEL:
    #model_wiki = KeyedVectors.load_word2vec_format(MODEL_PATH + 'ruwiki_20180420_300d.txt.bz2')
    #model.build_vocab([list(model_wiki.vocab.keys()) * min_word_count], update=True)
    model.intersect_word2vec_format(PRETRAINED_MODEL_PATH, lockf=1.0)
    print(f'vocab size after loading pretrained model: {len(model.wv.vocab)}')
# Out:
# vocab size after loading pretrained model: 530536

# %%
model.train(MyCorpus(), total_examples=total_examples, epochs=40)
model.save(MODEL_PATH + 'mdl')
print('model was saved')

f = open(MODEL_PATH + 'description.txt', 'w')
f.write('date: 28.04\n')
f.write('params: size=300, min_count=5, window=10, negative=15, iter=10, sg=1')
f.write(f'sourse: {SOURCE_PATH}\n')
f.write('cities: moscow, spb, london, nyc\n')
f.write(f'valid_langs: {valid_langs}\n')
print('success')
f.close()
# Out:
# iter 1 for moscow completed, posts: 15733857
# iter 1 for spb completed, posts: 12542201
#
# iter 1 completed
#
# iter 2 for moscow completed, posts: 15733857
# iter 2 for spb completed, posts: 12542201
#
# iter 2 completed
#
# iter 3 for moscow completed, posts: 15733857
# iter 3 for spb completed, posts: 12542201
#
# iter 3 completed
#
# iter 4 for moscow completed, posts: 15733857
# iter 4 for spb completed, posts: 12542201
#
# iter 4 completed
#
# iter 5 for moscow completed, posts: 15733857
# iter 5 for spb completed, posts: 12542201
#
# iter 5 completed
#
# iter 6 for moscow completed, posts: 15733857
# iter 6 for spb completed, posts: 12542201
#
# iter 6 completed
#
# iter 7 for moscow completed, posts: 15733857
# iter 7 for spb completed, posts: 12542201
#
# iter 7 completed
#
# iter 8 for moscow completed, posts: 15733857
# iter 8 for spb completed, posts: 12542201
#
# iter 8 completed
#
# iter 9 for moscow completed, posts: 15733857
# iter 9 for spb completed, posts: 12542201
#
# iter 9 completed
#
# iter 10 for moscow completed, posts: 15733857
# iter 10 for spb completed, posts: 12542201
#
# iter 10 completed
#
# iter 11 for moscow completed, posts: 15733857
# iter 11 for spb completed, posts: 12542201
#
# iter 11 completed
#
# iter 12 for moscow completed, posts: 15733857
# iter 12 for spb completed, posts: 12542201
#
# iter 12 completed
#
# iter 13 for moscow completed, posts: 15733857
# iter 13 for spb completed, posts: 12542201
#
# iter 13 completed
#
# iter 14 for moscow completed, posts: 15733857
# iter 14 for spb completed, posts: 12542201
#
# iter 14 completed
#
# iter 15 for moscow completed, posts: 15733857
# iter 15 for spb completed, posts: 12542201
#
# iter 15 completed
#
# iter 16 for moscow completed, posts: 15733857
# iter 16 for spb completed, posts: 12542201
#
# iter 16 completed
#
# iter 17 for moscow completed, posts: 15733857
# iter 17 for spb completed, posts: 12542201
#
# iter 17 completed
#
# iter 18 for moscow completed, posts: 15733857
# iter 18 for spb completed, posts: 12542201
#
# iter 18 completed
#
# iter 19 for moscow completed, posts: 15733857
# iter 19 for spb completed, posts: 12542201
#
# iter 19 completed
#
# iter 20 for moscow completed, posts: 15733857
# iter 20 for spb completed, posts: 12542201
#
# iter 20 completed
#
# iter 21 for moscow completed, posts: 15733857
# iter 21 for spb completed, posts: 12542201
#
# iter 21 completed
#
# iter 22 for moscow completed, posts: 15733857
# iter 22 for spb completed, posts: 12542201
#
# iter 22 completed
#
# iter 23 for moscow completed, posts: 15733857
# iter 23 for spb completed, posts: 12542201
#
# iter 23 completed
#
# iter 24 for moscow completed, posts: 15733857
# iter 24 for spb completed, posts: 12542201
#
# iter 24 completed
#
# iter 25 for moscow completed, posts: 15733857
# iter 25 for spb completed, posts: 12542201
#
# iter 25 completed
#
# iter 26 for moscow completed, posts: 15733857
# iter 26 for spb completed, posts: 12542201
#
# iter 26 completed
#
# iter 27 for moscow completed, posts: 15733857
# iter 27 for spb completed, posts: 12542201
#
# iter 27 completed
#
# iter 28 for moscow completed, posts: 15733857
# iter 28 for spb completed, posts: 12542201
#
# iter 28 completed
#
# iter 29 for moscow completed, posts: 15733857
# iter 29 for spb completed, posts: 12542201
#
# iter 29 completed
#
# iter 30 for moscow completed, posts: 15733857
# iter 30 for spb completed, posts: 12542201
#
# iter 30 completed
#
# iter 31 for moscow completed, posts: 15733857
# iter 31 for spb completed, posts: 12542201
#
# iter 31 completed
#
# iter 32 for moscow completed, posts: 15733857
# iter 32 for spb completed, posts: 12542201
#
# iter 32 completed
#
# iter 33 for moscow completed, posts: 15733857
# iter 33 for spb completed, posts: 12542201
#
# iter 33 completed
#
# iter 34 for moscow completed, posts: 15733857
# iter 34 for spb completed, posts: 12542201
#
# iter 34 completed
#
# iter 35 for moscow completed, posts: 15733857
# iter 35 for spb completed, posts: 12542201
